# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r'C:\Users\USER\Desktop\GitHub\Brasileirao-Analise\1. Data\Processed\data_exploratory.xlsx')

df['publico pagante'].hist(bins=30)
sns.boxplot(x=df['publico pagante'])

# #df.describe()
# df.head(8)
# Out:
# <Axes: xlabel='publico pagante'>

# %%
df['publico pagante'].value_counts().plot(kind='bar')
sns.countplot(x='publico pagante', data=df)
# Out:
# <Axes: xlabel='publico pagante', ylabel='count'>
# C:\Users\USER\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
